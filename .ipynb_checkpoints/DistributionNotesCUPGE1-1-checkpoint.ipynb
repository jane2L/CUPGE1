# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
notes_ = pd.read_csv("notes.csv",sep = ";",decimal = ",",dtype = np.float64)
notes = notes_[["DS 1", "DS 5", "DS 6"]]

notes_.head()
#notes.head()
# Out:
#         DS 1       DS 2       DS 3       DS 4       DS 5  DS 6
# 0   8.071639  14.362874  11.987841  17.393837  12.239654  16.7
# 1  11.119059   9.316937   6.975666   8.548873   5.100881   9.4
# 2  13.256388  14.046855  17.390187  14.497870  13.012426   1.9
# 3  11.016188  13.516071  10.008830   7.368767  14.520577  10.4
# 4  14.961724   9.557703   9.227365   6.986178   7.107409  14.4

# %%
#palette = sns.color_palette(palette='rainbow')
#palette = sns.color_palette(palette='viridis')
#palette = sns.color_palette(palette='twilight_shifted')
palette = sns.color_palette(palette='afmhot')
c = sns.boxplot(hue ="DS",x = "DS", y="notes",data = notes, palette = palette[0:5],boxprops=dict(alpha=.5))
sns.stripplot(hue  ="DS", x = "DS", y = "notes", data = notes,palette = palette[0:5],alpha = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 #palette = sns.color_palette(palette='rainbow')
#       2 #palette = sns.color_palette(palette='viridis')
#       3 #palette = sns.color_palette(palette='twilight_shifted')
#       4 palette = sns.color_palette(palette='afmhot')
# ----> 5 c = sns.boxplot(hue ="DS",x = "DS", y="notes",data = notes, palette = palette[0:5],boxprops=dict(alpha=.5))
#       6 sns.stripplot(hue  ="DS", x = "DS", y = "notes", data = notes,palette = palette[0:5],alpha = 1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
# ...

# %%
from scipy.stats import gaussian_kde
#sns.histplot(notes_["DS 4"],fill = True,label ="DS 4",alpha = 0.3)
sns.histplot(notes_["DS 5"],fill = True,label = "DS 5",alpha = 0.1)
sns.histplot(notes_["DS 6"],fill = True,label = "DS 6",alpha = 0.3)
#sns.histplot(notes_["DS 2"],fill = True)
#sns.kdeplot(notesDS3)
#sns.kdeplot(notesDS4)
# Out:
# <Axes: xlabel='DS 5', ylabel='Count'>

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
palette = sns.color_palette(palette='rainbow')
cmap = [palette[0],palette[2],palette[4],palette[5]]
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(notes, fill=True, cut = True, levels=1,  color="w", linewidths=2, thresh=20, ax=ax)
ax.set_xlim((2,20))  #
ax.set_ylim((0.003,0.06))  #
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([])  # Hide the Y-axis
plt.show()

# %%
np.linalg.inv([[1,0,-1],[1,-1,0],[-1,1,1]])
A = np.array([[-1,1,1],[0,1,1],[0,1,1]])
A*A*A
# Out:
# array([[-1,  1,  1],
#        [ 0,  1,  1],
#        [ 0,  1,  1]])
